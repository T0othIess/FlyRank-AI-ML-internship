# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/T0othIess/FlyRank-AI-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane 4: CTR/Engagement Opportunity Scoring. in week 1 notebook 01, discovery B showed that CTR sharply drops as the position tier gets worse.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# the question is what pages appear to have lower CTR than they should for their position.
# the decision is to decide which of those pages must be reviewed first for CTR imporvement.
# the action is made by an SEO specialist or a manager for content who can review the page's details, title,etc to improve CTR.
# the cost of a wrong recommendation, time and effort would b wasted trying to review a page thats falsly callsed as a CTR opportunity.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
print(f"Average CTR: {df["ctr"].mean():.4f}")
print(f"Average CTR for the top 10 pages based on position: {df[df["avg_position"] <= 10]["ctr"].mean():.4f}")
print(f"Number of pages with 500 and more impressions: {(df["impressions_90d"] >= 500).sum():,}") #note to self :, just adds the thousands ,
# Out:
# Average CTR: 0.5107
# Average CTR for the top 10 pages based on position: 0.7869
# Number of pages with 500 and more impressions: 16,726

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# what i can say is that CTR is very associated with positions just like the difference in avg CTR between all the data and top 10 pages.
#
# what i cant say is that changing like the title of the page will increase CTR, that can be discovered through experiments, also. i just observed data, i didnt discover anything. yet.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ x ] Every section above is filled — markdown thinking AND the code that backs it
# - [ x ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x ] No client names, URLs, or private queries anywhere
# - [ x ] My claims use careful words: observed, measured, directional, decision-support
# - [ x ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
